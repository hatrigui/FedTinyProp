# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
print("Project root added to sys.path")
# Out:
# Project root added to sys.path

# %%
import torch
import torch.nn 
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import os

from clients.federated_training import federated_training
from utils.data_partition import dirichlet_partition


torch.manual_seed(42)
np.random.seed(42)

# %%
import os

# Create results directory in the notebook directory
os.makedirs("results", exist_ok=True)
print("Results directory created at:", os.path.abspath("results"))
# Out:
# Results directory created at: c:\Users\la7tim\Desktop\Internship\FedTinyProp\notebooks\results

# %%
transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    
    
trainset = datasets.MNIST('./data', train=True, download=True, transform=transform)
testset = datasets.MNIST('./data', train=False, transform=transform)
    
    

print(f"Training set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
print(f"Number of classes: {len(trainset.classes)}")
# Out:
# Training set size: 60000
# Test set size: 10000
# Number of classes: 10

# %%
num_clients = 5
partitions = {
    "IID":   dirichlet_partition(trainset, num_clients=num_clients, alpha=0.01),
}
# Out:
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\data_partition.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   labels = np.array(dataset.targets)

# %%
from utils.partitions_visualization import print_partition_stats, plot_data_distribution

# Print detailed statistics
print_partition_stats(partitions, "MNIST")

# Create comprehensive visualization
fig = plot_data_distribution(partitions, "MNIST")
plt.show()
# Out:
# === Partition Statistics for MNIST ===
#
# IID Partition:
# Total samples: 60000
#
# Per-client distribution:
# Client 0: 18057 samples (30.09%)
# Client 1: 11340 samples (18.90%)
# Client 2: 12593 samples (20.99%)
# Client 3: 12076 samples (20.13%)
# Client 4: 5934 samples (9.89%)
# [Debug] Number of classes: 10
# [Debug] Number of clients: 5
# [Debug] Processing client 0 with 18057 samples
# [Debug] Client 0 has 18057 valid targets
# [Debug] Client 0 class counts: [1.000e+00 1.000e+00 5.953e+03 1.000e+00 5.837e+03 1.000e+00 1.000e+00
#  6.260e+03 1.000e+00 1.000e+00]
# [Debug] Processing client 1 with 11340 samples
# [Debug] Client 1 has 11340 valid targets
# [Debug] Client 1 class counts: [1.000e+00 1.000e+00 1.000e+00 3.000e+00 1.000e+00 5.417e+03 5.913e+03
#  1.000e+00 1.000e+00 1.000e+00]
# [Debug] Processing client 2 with 12593 samples
# [Debug] Client 2 has 12593 valid targets
# [Debug] Client 2 class counts: [1.000e+00 6.738e+03 1.000e+00 1.000e+00 2.000e+00 1.000e+00 1.000e+00
#  1.000e+00 5.846e+03 1.000e+00]
# [Debug] Processing client 3 with 12076 samples
# [Debug] Client 3 has 12076 valid targets
# [Debug] Client 3 class counts: [1.000e+00 1.000e+00 1.000e+00 6.125e+03 1.000e+00 1.000e+00 1.000e+00
#  1.000e+00 1.000e+00 5.943e+03]
# [Debug] Processing client 4 with 5934 samples
# [Debug] Client 4 has 5934 valid targets
# [Debug] Client 4 class counts: [5.919e+03 1.000e+00 2.000e+00 1.000e+00 1.000e+00 1.000e+00 2.000e+00
#  2.000e+00 2.000e+00 3.000e+00]
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\partitions_visualization.py:17: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   targets = np.array(partitions[0].dataset.targets)

# %%
from models.config import get_tinyprop_config

config = get_tinyprop_config("mnist")
config['quantization_bits'] = 8  # Explicit for clarity

print("\nModel Configuration:")
for key, value in config.items():
    print(f"{key}: {value}")

tinyprop_params = config["tinyprop_params"]
print("\nTinyProp Parameters:")
print(f"S_min: {tinyprop_params.S_min}")
print(f"S_max: {tinyprop_params.S_max}")
print(f"zeta: {tinyprop_params.zeta}")
print(f"number_of_layers: {tinyprop_params.number_of_layers}")
# Out:
# Model Configuration:
# tinyprop_params: <models.tinyProp.TinyPropParams object at 0x000002471EA44590>
# optimizer: {'type': 'sgd', 'lr': 0.0005, 'momentum': 0.7, 'weight_decay': 0.0001}
# lr_scheduler: {'type': 'cosine', 'T_max': 100, 'eta_min': 1e-05, 'warmup_epochs': 5, 'warmup_start_lr': 1e-05}
# gradient_clip: 1.0
# batch_size: 32
# num_epochs: 1
# label_smoothing: 0.1
# quantization: {'bits': 8, 'enabled': True, 'adaptive': True, 'min_bits': 4, 'max_bits': 16, 'layer_specific': True, 'error_threshold': 0.01, 'momentum': 0.9}
# quantization_bits: 8
#
# TinyProp Parameters:
# S_min: 0.5
# S_max: 0.95
# zeta: 0.5
# number_of_layers: 4

# %%
from clients.aggregators import sparse_fedavg_aggregate
def train_and_analyze_partition(partition_name, client_datasets, tinyprop_params):
    print(f"\nTraining on partition: {partition_name.upper()}")
    
    # Get base config
    config = get_tinyprop_config('mnist')
    
    # Run training
    model, metrics = federated_training(
        client_datasets=client_datasets,
        model_name='mnist',
        testset=testset,
        tinyprop_params=tinyprop_params,
        aggregator_fn=sparse_fedavg_aggregate,
        rounds=100,
        device="cuda" if torch.cuda.is_available() else "cpu",
        local_epochs=1,
        early_stopping_patience=100,
        early_stopping_delta=0.001,
        csv_log_path=f'results/mnist_metrics.csv',  # Single CSV file for all partitions
        initial_sparsity=tinyprop_params.S_min,
        target_sparsity=tinyprop_params.S_max,
        energy_budget=1000,
        save_dir='results',
        save_interval=1,
        use_dense_baseline=False,
        use_fedprox= False,
        fedprox_mu= 0.01,
        use_rigl= True,
        rigl_initial_sparsity= 0.5,
        rigl_target_sparsity= 0.95,
        rigl_update_interval= 100,
        rigl_final_update_epoch= 100,
    )
    
    # Print summary statistics
    print(f"\nTraining Summary for {partition_name.upper()}:")
    print(f"Final Accuracy: {metrics['accuracy'][-1]:.4f}")
    print(f"Average Sparsity: {np.mean(metrics['sparsity']):.4f}")
    print(f"Average Compression Ratio: {np.mean(metrics['compression_ratio']):.4f}")
    print(f"Average Effective Compute Ratio: {np.mean(metrics['effective_compute_ratio']):.4f}")
    print(f"Total Communication Cost: {metrics['communication'][-1]/1024:.2f} KB")
    print(f"Total Memory Saved: {metrics['memory_saved'][-1]:.2f} MB")
    
    return model, metrics

# Run training for each partition
partition_results = {}
for strategy_name, client_datasets in partitions.items():
    print(f"\nStarting training for {strategy_name.upper()} partition...")
    try:
        model, metrics = train_and_analyze_partition(strategy_name, client_datasets, tinyprop_params)
        partition_results[strategy_name] = {
            'model': model,
            'metrics': metrics
        }
        print(f"Completed training for {strategy_name.upper()}")
    except Exception as e:
        print(f"Error in {strategy_name.upper()}: {str(e)}")
        continue
# Out:
# Starting training for IID partition...
#
# Training on partition: IID
#
# [Training Debug] Initializing clients...
# [Training Debug] Client 0 initialized with 18057 samples
# [Training Debug] Client 1 initialized with 11340 samples
# [Training Debug] Client 2 initialized with 12593 samples
# [Training Debug] Client 3 initialized with 12076 samples
# [Training Debug] Client 4 initialized with 5934 samples
#
# Round 1/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31733.71KB
# Total communication: 63488.91KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 4.23KB
#   conv1.bias: 0.41KB
#   conv2.weight: 270.68KB
#   conv2.bias: 0.80KB
#   fc1.weight: 31437.08KB
#   fc1.bias: 1.58KB
#   fc2.weight: 18.80KB
#   fc2.bias: 0.14KB
# [Training Debug] RigL mask updates: 15
#
# [INFO] Updated metrics saved to results/mnist_metrics.csv
# [INFO] Appended round 1 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 1/100] Accuracy: 12.0100, Sparsity: 0.5012
# [Training Debug][Round 1/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 1/100] Communication: 65012639.00 bytes
# [Training Debug][Round 1/100] Compression ratio: 1.00
# [Training Debug][Round 1/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 1/100] RigL sparsity: 0.5012
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round1.pt
#
# Round 2/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 32045.22KB
# Total communication: 63800.41KB
# Compression ratio: 0.99x
#
# Per-layer communication:
#   conv1.weight: 4.27KB
#   conv1.bias: 0.38KB
#   conv2.weight: 273.32KB
#   conv2.bias: 0.77KB
#   fc1.weight: 31745.83KB
#   fc1.bias: 1.55KB
#   fc2.weight: 18.98KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 35
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 2 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 2/100] Accuracy: 11.9580, Sparsity: 0.5061
# [Training Debug][Round 2/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 2/100] Communication: 65331621.00 bytes
# [Training Debug][Round 2/100] Compression ratio: 1.00
# [Training Debug][Round 2/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 2/100] RigL sparsity: 0.5061
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round2.pt
#
# Round 3/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 32522.20KB
# Total communication: 64277.40KB
# Compression ratio: 0.98x
#
# Per-layer communication:
#   conv1.weight: 4.33KB
#   conv1.bias: 0.38KB
#   conv2.weight: 277.40KB
#   conv2.bias: 0.77KB
#   fc1.weight: 32218.39KB
#   fc1.bias: 1.55KB
#   fc2.weight: 19.27KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 53
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 3 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 3/100] Accuracy: 13.3740, Sparsity: 0.5136
# [Training Debug][Round 3/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 3/100] Communication: 65820054.00 bytes
# [Training Debug][Round 3/100] Compression ratio: 1.00
# [Training Debug][Round 3/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 3/100] RigL sparsity: 0.5136
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round3.pt
#
# Round 4/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 33272.88KB
# Total communication: 65028.07KB
# Compression ratio: 0.95x
#
# Per-layer communication:
#   conv1.weight: 4.44KB
#   conv1.bias: 0.38KB
#   conv2.weight: 283.80KB
#   conv2.bias: 0.77KB
#   fc1.weight: 32962.15KB
#   fc1.bias: 1.52KB
#   fc2.weight: 19.71KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 73
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 4 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 4/100] Accuracy: 16.8780, Sparsity: 0.5255
# [Training Debug][Round 4/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 4/100] Communication: 66588748.00 bytes
# [Training Debug][Round 4/100] Compression ratio: 1.00
# [Training Debug][Round 4/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 4/100] RigL sparsity: 0.5255
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round4.pt
#
# Round 5/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 34137.14KB
# Total communication: 65892.34KB
# Compression ratio: 0.93x
#
# Per-layer communication:
#   conv1.weight: 4.56KB
#   conv1.bias: 0.38KB
#   conv2.weight: 291.16KB
#   conv2.bias: 0.74KB
#   fc1.weight: 33818.50KB
#   fc1.bias: 1.48KB
#   fc2.weight: 20.21KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 91
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 5 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 5/100] Accuracy: 18.7260, Sparsity: 0.5392
# [Training Debug][Round 5/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 5/100] Communication: 67473754.00 bytes
# [Training Debug][Round 5/100] Compression ratio: 1.00
# [Training Debug][Round 5/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 5/100] RigL sparsity: 0.5392
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round5.pt
#
# Round 6/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 35188.63KB
# Total communication: 66943.82KB
# Compression ratio: 0.90x
#
# Per-layer communication:
#   conv1.weight: 4.68KB
#   conv1.bias: 0.36KB
#   conv2.weight: 300.13KB
#   conv2.bias: 0.72KB
#   fc1.weight: 34860.33KB
#   fc1.bias: 1.44KB
#   fc2.weight: 20.84KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 110
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 6 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 6/100] Accuracy: 19.3900, Sparsity: 0.5558
# [Training Debug][Round 6/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 6/100] Communication: 68550475.00 bytes
# [Training Debug][Round 6/100] Compression ratio: 1.00
# [Training Debug][Round 6/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 6/100] RigL sparsity: 0.5558
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round6.pt
#
# Round 7/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 36411.54KB
# Total communication: 68166.73KB
# Compression ratio: 0.87x
#
# Per-layer communication:
#   conv1.weight: 4.85KB
#   conv1.bias: 0.35KB
#   conv2.weight: 310.58KB
#   conv2.bias: 0.69KB
#   fc1.weight: 36072.00KB
#   fc1.bias: 1.39KB
#   fc2.weight: 21.57KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 129
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 7 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 7/100] Accuracy: 19.6980, Sparsity: 0.5751
# [Training Debug][Round 7/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 7/100] Communication: 69802734.00 bytes
# [Training Debug][Round 7/100] Compression ratio: 1.00
# [Training Debug][Round 7/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 7/100] RigL sparsity: 0.5751
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round7.pt
#
# Round 8/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 37786.79KB
# Total communication: 69541.99KB
# Compression ratio: 0.84x
#
# Per-layer communication:
#   conv1.weight: 5.04KB
#   conv1.bias: 0.34KB
#   conv2.weight: 322.27KB
#   conv2.bias: 0.67KB
#   fc1.weight: 37434.66KB
#   fc1.bias: 1.33KB
#   fc2.weight: 22.38KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 148
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 8 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 8/100] Accuracy: 19.9660, Sparsity: 0.5968
# [Training Debug][Round 8/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 8/100] Communication: 71210998.00 bytes
# [Training Debug][Round 8/100] Compression ratio: 1.00
# [Training Debug][Round 8/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 8/100] RigL sparsity: 0.5968
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round8.pt
#
# Round 9/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 39137.74KB
# Total communication: 70892.93KB
# Compression ratio: 0.81x
#
# Per-layer communication:
#   conv1.weight: 5.22KB
#   conv1.bias: 0.32KB
#   conv2.weight: 333.83KB
#   conv2.bias: 0.63KB
#   fc1.weight: 38773.18KB
#   fc1.bias: 1.26KB
#   fc2.weight: 23.19KB
#   fc2.bias: 0.11KB
# [Training Debug] RigL mask updates: 166
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 9 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 9/100] Accuracy: 20.8060, Sparsity: 0.6182
# [Training Debug][Round 9/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 9/100] Communication: 72594365.00 bytes
# [Training Debug][Round 9/100] Compression ratio: 1.00
# [Training Debug][Round 9/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 9/100] RigL sparsity: 0.6182
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round9.pt
#
# Round 10/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 40639.94KB
# Total communication: 72395.14KB
# Compression ratio: 0.78x
#
# Per-layer communication:
#   conv1.weight: 5.42KB
#   conv1.bias: 0.30KB
#   conv2.weight: 346.64KB
#   conv2.bias: 0.60KB
#   fc1.weight: 40261.62KB
#   fc1.bias: 1.20KB
#   fc2.weight: 24.07KB
#   fc2.bias: 0.09KB
# [Training Debug] RigL mask updates: 185
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 10 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 10/100] Accuracy: 21.0740, Sparsity: 0.6419
# [Training Debug][Round 10/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 10/100] Communication: 74132622.00 bytes
# [Training Debug][Round 10/100] Compression ratio: 1.00
# [Training Debug][Round 10/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 10/100] RigL sparsity: 0.6419
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round10.pt
#
# Round 11/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 42263.14KB
# Total communication: 74018.33KB
# Compression ratio: 0.75x
#
# Per-layer communication:
#   conv1.weight: 5.63KB
#   conv1.bias: 0.28KB
#   conv2.weight: 360.48KB
#   conv2.bias: 0.56KB
#   fc1.weight: 41869.94KB
#   fc1.bias: 1.12KB
#   fc2.weight: 25.04KB
#   fc2.bias: 0.09KB
# [Training Debug] RigL mask updates: 205
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 11 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 11/100] Accuracy: 21.4980, Sparsity: 0.6675
# [Training Debug][Round 11/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 11/100] Communication: 75794774.00 bytes
# [Training Debug][Round 11/100] Compression ratio: 1.00
# [Training Debug][Round 11/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 11/100] RigL sparsity: 0.6675
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round11.pt
#
# Round 12/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 43733.03KB
# Total communication: 75488.23KB
# Compression ratio: 0.73x
#
# Per-layer communication:
#   conv1.weight: 5.82KB
#   conv1.bias: 0.26KB
#   conv2.weight: 373.03KB
#   conv2.bias: 0.52KB
#   fc1.weight: 43326.37KB
#   fc1.bias: 1.04KB
#   fc2.weight: 25.90KB
#   fc2.bias: 0.08KB
# [Training Debug] RigL mask updates: 223
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 12 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 12/100] Accuracy: 21.6420, Sparsity: 0.6908
# [Training Debug][Round 12/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 12/100] Communication: 77299947.00 bytes
# [Training Debug][Round 12/100] Compression ratio: 1.00
# [Training Debug][Round 12/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 12/100] RigL sparsity: 0.6908
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round12.pt
#
# Round 13/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 45349.78KB
# Total communication: 77104.98KB
# Compression ratio: 0.70x
#
# Per-layer communication:
#   conv1.weight: 6.04KB
#   conv1.bias: 0.24KB
#   conv2.weight: 386.80KB
#   conv2.bias: 0.48KB
#   fc1.weight: 44928.30KB
#   fc1.bias: 0.97KB
#   fc2.weight: 26.86KB
#   fc2.bias: 0.08KB
# [Training Debug] RigL mask updates: 243
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 13 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 13/100] Accuracy: 21.6940, Sparsity: 0.7163
# [Training Debug][Round 13/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 13/100] Communication: 78955495.00 bytes
# [Training Debug][Round 13/100] Compression ratio: 1.00
# [Training Debug][Round 13/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 13/100] RigL sparsity: 0.7163
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round13.pt
#
# Round 14/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 46735.39KB
# Total communication: 78490.58KB
# Compression ratio: 0.68x
#
# Per-layer communication:
#   conv1.weight: 6.23KB
#   conv1.bias: 0.23KB
#   conv2.weight: 398.63KB
#   conv2.bias: 0.45KB
#   fc1.weight: 46301.20KB
#   fc1.bias: 0.89KB
#   fc2.weight: 27.68KB
#   fc2.bias: 0.07KB
# [Training Debug] RigL mask updates: 261
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 14 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 14/100] Accuracy: 21.6880, Sparsity: 0.7382
# [Training Debug][Round 14/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 14/100] Communication: 80374358.00 bytes
# [Training Debug][Round 14/100] Compression ratio: 1.00
# [Training Debug][Round 14/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 14/100] RigL sparsity: 0.7382
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round14.pt
#
# Round 15/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 48108.38KB
# Total communication: 79863.57KB
# Compression ratio: 0.66x
#
# Per-layer communication:
#   conv1.weight: 6.40KB
#   conv1.bias: 0.21KB
#   conv2.weight: 410.32KB
#   conv2.bias: 0.42KB
#   fc1.weight: 47661.64KB
#   fc1.bias: 0.82KB
#   fc2.weight: 28.50KB
#   fc2.bias: 0.07KB
# [Training Debug] RigL mask updates: 279
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 15 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 15/100] Accuracy: 21.8760, Sparsity: 0.7599
# [Training Debug][Round 15/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 15/100] Communication: 81780296.00 bytes
# [Training Debug][Round 15/100] Compression ratio: 1.00
# [Training Debug][Round 15/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 15/100] RigL sparsity: 0.7599
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round15.pt
#
# Round 16/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 49407.67KB
# Total communication: 81162.86KB
# Compression ratio: 0.64x
#
# Per-layer communication:
#   conv1.weight: 6.58KB
#   conv1.bias: 0.19KB
#   conv2.weight: 421.43KB
#   conv2.bias: 0.38KB
#   fc1.weight: 48949.01KB
#   fc1.bias: 0.75KB
#   fc2.weight: 29.26KB
#   fc2.bias: 0.07KB
# [Training Debug] RigL mask updates: 298
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 16 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 16/100] Accuracy: 21.6600, Sparsity: 0.7804
# [Training Debug][Round 16/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 16/100] Communication: 83110772.00 bytes
# [Training Debug][Round 16/100] Compression ratio: 1.00
# [Training Debug][Round 16/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 16/100] RigL sparsity: 0.7804
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round16.pt
#
# Round 17/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 50589.30KB
# Total communication: 82344.49KB
# Compression ratio: 0.63x
#
# Per-layer communication:
#   conv1.weight: 6.75KB
#   conv1.bias: 0.17KB
#   conv2.weight: 431.51KB
#   conv2.bias: 0.34KB
#   fc1.weight: 50119.82KB
#   fc1.bias: 0.68KB
#   fc2.weight: 29.96KB
#   fc2.bias: 0.06KB
# [Training Debug] RigL mask updates: 317
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 17 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 17/100] Accuracy: 21.3580, Sparsity: 0.7991
# [Training Debug][Round 17/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 17/100] Communication: 84320762.00 bytes
# [Training Debug][Round 17/100] Compression ratio: 1.00
# [Training Debug][Round 17/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 17/100] RigL sparsity: 0.7991
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round17.pt
#
# Round 18/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51629.36KB
# Total communication: 83384.56KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 6.88KB
#   conv1.bias: 0.16KB
#   conv2.weight: 440.37KB
#   conv2.bias: 0.32KB
#   fc1.weight: 51150.37KB
#   fc1.bias: 0.63KB
#   fc2.weight: 30.59KB
#   fc2.bias: 0.06KB
# [Training Debug] RigL mask updates: 335
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 18 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 18/100] Accuracy: 21.5220, Sparsity: 0.8155
# [Training Debug][Round 18/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 18/100] Communication: 85385788.00 bytes
# [Training Debug][Round 18/100] Compression ratio: 1.00
# [Training Debug][Round 18/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 18/100] RigL sparsity: 0.8155
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round18.pt
#
# Round 19/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 52600.08KB
# Total communication: 84355.28KB
# Compression ratio: 0.60x
#
# Per-layer communication:
#   conv1.weight: 7.01KB
#   conv1.bias: 0.14KB
#   conv2.weight: 448.67KB
#   conv2.bias: 0.29KB
#   fc1.weight: 52112.19KB
#   fc1.bias: 0.58KB
#   fc2.weight: 31.16KB
#   fc2.bias: 0.05KB
# [Training Debug] RigL mask updates: 354
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 19 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 19/100] Accuracy: 21.4380, Sparsity: 0.8309
# [Training Debug][Round 19/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 19/100] Communication: 86379804.00 bytes
# [Training Debug][Round 19/100] Compression ratio: 1.00
# [Training Debug][Round 19/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 19/100] RigL sparsity: 0.8309
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round19.pt
#
# Round 20/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 53570.44KB
# Total communication: 85325.64KB
# Compression ratio: 0.59x
#
# Per-layer communication:
#   conv1.weight: 7.14KB
#   conv1.bias: 0.14KB
#   conv2.weight: 456.95KB
#   conv2.bias: 0.27KB
#   fc1.weight: 53073.63KB
#   fc1.bias: 0.53KB
#   fc2.weight: 31.73KB
#   fc2.bias: 0.05KB
# [Training Debug] RigL mask updates: 374
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 20 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 20/100] Accuracy: 21.4100, Sparsity: 0.8462
# [Training Debug][Round 20/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 20/100] Communication: 87373452.00 bytes
# [Training Debug][Round 20/100] Compression ratio: 1.00
# [Training Debug][Round 20/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 20/100] RigL sparsity: 0.8462
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round20.pt
#
# Round 21/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 54387.65KB
# Total communication: 86142.85KB
# Compression ratio: 0.58x
#
# Per-layer communication:
#   conv1.weight: 7.25KB
#   conv1.bias: 0.12KB
#   conv2.weight: 463.91KB
#   conv2.bias: 0.24KB
#   fc1.weight: 53883.37KB
#   fc1.bias: 0.48KB
#   fc2.weight: 32.22KB
#   fc2.bias: 0.05KB
# [Training Debug] RigL mask updates: 392
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 21 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 21/100] Accuracy: 21.1080, Sparsity: 0.8591
# [Training Debug][Round 21/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 21/100] Communication: 88210278.00 bytes
# [Training Debug][Round 21/100] Compression ratio: 1.00
# [Training Debug][Round 21/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 21/100] RigL sparsity: 0.8591
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round21.pt
#
# Round 22/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 55090.38KB
# Total communication: 86845.57KB
# Compression ratio: 0.58x
#
# Per-layer communication:
#   conv1.weight: 7.34KB
#   conv1.bias: 0.11KB
#   conv2.weight: 469.90KB
#   conv2.bias: 0.22KB
#   fc1.weight: 54579.68KB
#   fc1.bias: 0.44KB
#   fc2.weight: 32.63KB
#   fc2.bias: 0.05KB
# [Training Debug] RigL mask updates: 411
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 22 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 22/100] Accuracy: 21.2940, Sparsity: 0.8702
# [Training Debug][Round 22/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 22/100] Communication: 88929867.00 bytes
# [Training Debug][Round 22/100] Compression ratio: 1.00
# [Training Debug][Round 22/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 22/100] RigL sparsity: 0.8702
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round22.pt
#
# Round 23/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 55680.35KB
# Total communication: 87435.55KB
# Compression ratio: 0.57x
#
# Per-layer communication:
#   conv1.weight: 7.42KB
#   conv1.bias: 0.11KB
#   conv2.weight: 474.94KB
#   conv2.bias: 0.21KB
#   fc1.weight: 55164.23KB
#   fc1.bias: 0.42KB
#   fc2.weight: 32.99KB
#   fc2.bias: 0.05KB
# [Training Debug] RigL mask updates: 428
# [Error] Failed to save metrics: All arrays must be of the same length
# ...
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 93/100] Accuracy: 40.2480, Sparsity: 0.9500
# [Training Debug][Round 93/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 93/100] Communication: 85440627.00 bytes
# [Training Debug][Round 93/100] Compression ratio: 1.00
# [Training Debug][Round 93/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 93/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round93.pt
#
# Round 94/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51609.55KB
# Total communication: 83364.75KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.57KB
#   conv1.bias: 0.04KB
#   conv2.weight: 454.74KB
#   conv2.bias: 0.09KB
#   fc1.weight: 51112.12KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.80KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1763
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 94 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 94/100] Accuracy: 41.2960, Sparsity: 0.9500
# [Training Debug][Round 94/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 94/100] Communication: 85365499.00 bytes
# [Training Debug][Round 94/100] Compression ratio: 1.00
# [Training Debug][Round 94/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 94/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round94.pt
#
# Round 95/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51492.31KB
# Total communication: 83247.51KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.55KB
#   conv1.bias: 0.04KB
#   conv2.weight: 451.87KB
#   conv2.bias: 0.09KB
#   fc1.weight: 50997.84KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.72KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1782
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 95 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 95/100] Accuracy: 42.7320, Sparsity: 0.9500
# [Training Debug][Round 95/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 95/100] Communication: 85245447.00 bytes
# [Training Debug][Round 95/100] Compression ratio: 1.00
# [Training Debug][Round 95/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 95/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round95.pt
#
# Round 96/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51518.37KB
# Total communication: 83273.56KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.52KB
#   conv1.bias: 0.04KB
#   conv2.weight: 449.43KB
#   conv2.bias: 0.09KB
#   fc1.weight: 51026.27KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.82KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1800
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 96 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 96/100] Accuracy: 43.7660, Sparsity: 0.9500
# [Training Debug][Round 96/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 96/100] Communication: 85272129.00 bytes
# [Training Debug][Round 96/100] Compression ratio: 1.00
# [Training Debug][Round 96/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 96/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round96.pt
#
# Round 97/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51512.03KB
# Total communication: 83267.23KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.50KB
#   conv1.bias: 0.04KB
#   conv2.weight: 446.79KB
#   conv2.bias: 0.09KB
#   fc1.weight: 51022.64KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.77KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1820
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 97 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 97/100] Accuracy: 45.0920, Sparsity: 0.9500
# [Training Debug][Round 97/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 97/100] Communication: 85265643.00 bytes
# [Training Debug][Round 97/100] Compression ratio: 1.00
# [Training Debug][Round 97/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 97/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round97.pt
#
# Round 98/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51385.66KB
# Total communication: 83140.86KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.49KB
#   conv1.bias: 0.04KB
#   conv2.weight: 445.56KB
#   conv2.bias: 0.09KB
#   fc1.weight: 50897.55KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.75KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1838
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 98 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 98/100] Accuracy: 46.3520, Sparsity: 0.9500
# [Training Debug][Round 98/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 98/100] Communication: 85136239.00 bytes
# [Training Debug][Round 98/100] Compression ratio: 1.00
# [Training Debug][Round 98/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 98/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round98.pt
#
# Round 99/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51356.48KB
# Total communication: 83111.67KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.42KB
#   conv1.bias: 0.04KB
#   conv2.weight: 443.59KB
#   conv2.bias: 0.09KB
#   fc1.weight: 50870.41KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.73KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1858
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 99 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 99/100] Accuracy: 47.5340, Sparsity: 0.9500
# [Training Debug][Round 99/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 99/100] Communication: 85106355.00 bytes
# [Training Debug][Round 99/100] Compression ratio: 1.00
# [Training Debug][Round 99/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 99/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round99.pt
#
# Round 100/100
#
# [Training Debug] Training client 0
#
# [Training Debug] Training client 1
#
# [Training Debug] Training client 2
#
# [Training Debug] Training client 3
#
# [Training Debug] Training client 4
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 40/1625866
# Dense updates: 0
# Sparse updates: 40
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 51329.26KB
# Total communication: 83084.46KB
# Compression ratio: 0.62x
#
# Per-layer communication:
#   conv1.weight: 7.44KB
#   conv1.bias: 0.04KB
#   conv2.weight: 442.67KB
#   conv2.bias: 0.09KB
#   fc1.weight: 50844.08KB
#   fc1.bias: 0.16KB
#   fc2.weight: 34.74KB
#   fc2.bias: 0.04KB
# [Training Debug] RigL mask updates: 1878
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 100 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'rigl_sparsity': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [Training Debug][Round 100/100] Accuracy: 48.3480, Sparsity: 0.9500
# [Training Debug][Round 100/100] FLOPs: 7308219075.60, Memory: 0.00 bytes
# [Training Debug][Round 100/100] Communication: 85078487.00 bytes
# [Training Debug][Round 100/100] Compression ratio: 1.00
# [Training Debug][Round 100/100] Skipped batches: 0, Effective compute ratio: 1.0000
# [Training Debug][Round 100/100] RigL sparsity: 0.9500
# [INFO] Saved intermediate rigl model checkpoint to results\checkpoints\rigl_mnist_round100.pt
#
# [INFO] Saved rigl model checkpoint to results\checkpoints\rigl_mnist.pt
# [INFO] Saved full rigl checkpoint with metrics to results\checkpoints\rigl_mnist_full.pt
# Error in IID: too many values to unpack (expected 2)
