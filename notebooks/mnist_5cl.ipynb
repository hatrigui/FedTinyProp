# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
print("Project root added to sys.path")
# Out:
# Project root added to sys.path

# %%
import torch
import torch.nn 
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import os

from clients.federated_training import federated_training
from utils.data_partition import dirichlet_partition


torch.manual_seed(42)
np.random.seed(42)

# %%
import os

# Create results directory in the notebook directory
os.makedirs("results", exist_ok=True)
print("Results directory created at:", os.path.abspath("results"))
# Out:
# Results directory created at: c:\Users\la7tim\Desktop\Internship\FedTinyProp\notebooks\results

# %%
transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    
    
trainset = datasets.MNIST('./data', train=True, download=True, transform=transform)
testset = datasets.MNIST('./data', train=False, transform=transform)
    
    

print(f"Training set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
print(f"Number of classes: {len(trainset.classes)}")
# Out:
# Training set size: 60000
# Test set size: 10000
# Number of classes: 10

# %%
num_clients = 5
partitions = {
    "noniid":   dirichlet_partition(trainset, num_clients=num_clients, alpha=1000),
}
# Out:
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\data_partition.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   labels = np.array(dataset.targets)

# %%
from utils.partitions_visualization import print_partition_stats, plot_data_distribution

# Print detailed statistics
print_partition_stats(partitions, "MNIST")

# Create comprehensive visualization
fig = plot_data_distribution(partitions, "MNIST")
plt.show()
# Out:
# === Partition Statistics for MNIST ===
#
# NONIID Partition:
# Total samples: 60000
#
# Per-client distribution:
# Client 0: 12232 samples (20.39%)
# Client 1: 11966 samples (19.94%)
# Client 2: 11979 samples (19.96%)
# Client 3: 11795 samples (19.66%)
# Client 4: 12028 samples (20.05%)
# [Debug] Number of classes: 10
# [Debug] Number of clients: 5
# [Debug] Processing client 0 with 12232 samples
# [Debug] Client 0 has 12232 valid targets
# [Debug] Client 0 class counts: [1182. 1335. 1240. 1297. 1175. 1091. 1208. 1316. 1159. 1229.]
# [Debug] Processing client 1 with 11966 samples
# [Debug] Client 1 has 11966 valid targets
# [Debug] Client 1 class counts: [1192. 1340. 1202. 1192. 1202. 1123. 1178. 1202. 1174. 1161.]
# [Debug] Processing client 2 with 11979 samples
# [Debug] Client 2 has 11979 valid targets
# [Debug] Client 2 class counts: [1187. 1340. 1154. 1286. 1152. 1051. 1164. 1285. 1183. 1177.]
# [Debug] Processing client 3 with 11795 samples
# [Debug] Client 3 has 11795 valid targets
# [Debug] Client 3 class counts: [1202. 1369. 1151. 1155. 1106. 1035. 1156. 1228. 1167. 1226.]
# [Debug] Processing client 4 with 12028 samples
# [Debug] Client 4 has 12028 valid targets
# [Debug] Client 4 class counts: [1160. 1358. 1211. 1201. 1207. 1121. 1212. 1234. 1168. 1156.]
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\partitions_visualization.py:17: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   targets = np.array(partitions[0].dataset.targets)

# %%
from models.config import get_tinyprop_config

config = get_tinyprop_config("mnist")
config['quantization_bits'] = 8  # Explicit for clarity

print("\nModel Configuration:")
for key, value in config.items():
    print(f"{key}: {value}")

tinyprop_params = config["tinyprop_params"]
print("\nTinyProp Parameters:")
print(f"S_min: {tinyprop_params.S_min}")
print(f"S_max: {tinyprop_params.S_max}")
print(f"zeta: {tinyprop_params.zeta}")
print(f"number_of_layers: {tinyprop_params.number_of_layers}")
# Out:
# Model Configuration:
# tinyprop_params: <models.tinyProp.TinyPropParams object at 0x0000014125654C10>
# optimizer: {'type': 'sgd', 'lr': 0.0005, 'momentum': 0.7, 'weight_decay': 0.0001}
# lr_scheduler: {'type': 'cosine', 'T_max': 100, 'eta_min': 1e-05, 'warmup_epochs': 5, 'warmup_start_lr': 1e-05}
# gradient_clip: 1.0
# batch_size: 32
# num_epochs: 1
# label_smoothing: 0.1
# quantization: {'bits': 8, 'enabled': True, 'adaptive': True, 'min_bits': 4, 'max_bits': 16, 'layer_specific': True, 'error_threshold': 0.01, 'momentum': 0.9}
# quantization_bits: 8
#
# TinyProp Parameters:
# S_min: 0.5
# S_max: 0.95
# zeta: 0.5
# number_of_layers: 4

# %%
from clients.aggregators import sparse_fedavg_aggregate
def train_and_analyze_partition(partition_name, client_datasets, tinyprop_params):
    print(f"\nTraining on partition: {partition_name.upper()}")
    
    # Get base config
    config = get_tinyprop_config('mnist')
    
    # Run training
    model, metrics = federated_training(
        client_datasets=client_datasets,
        model_name='mnist',
        testset=testset,
        tinyprop_params=tinyprop_params,
        aggregator_fn=sparse_fedavg_aggregate,
        rounds=100,
        device="cuda" if torch.cuda.is_available() else "cpu",
        local_epochs=1,
        early_stopping_patience=100,
        early_stopping_delta=0.001,
        csv_log_path=f'results/mnist_metrics.csv',  # Single CSV file for all partitions
        initial_sparsity=tinyprop_params.S_min,
        target_sparsity=tinyprop_params.S_max,
        energy_budget=1000,
        save_dir='results',
        save_interval=1,
        use_dense_baseline=False
    )
    
    # Print summary statistics
    print(f"\nTraining Summary for {partition_name.upper()}:")
    print(f"Final Accuracy: {metrics['accuracy'][-1]:.4f}")
    print(f"Average Sparsity: {np.mean(metrics['sparsity']):.4f}")
    print(f"Average Compression Ratio: {np.mean(metrics['compression_ratio']):.4f}")
    print(f"Average Effective Compute Ratio: {np.mean(metrics['effective_compute_ratio']):.4f}")
    print(f"Total Communication Cost: {metrics['communication'][-1]/1024:.2f} KB")
    print(f"Total Memory Saved: {metrics['memory_saved'][-1]:.2f} MB")
    
    return model, metrics

# Run training for each partition
partition_results = {}
for strategy_name, client_datasets in partitions.items():
    print(f"\nStarting training for {strategy_name.upper()} partition...")
    try:
        model, metrics = train_and_analyze_partition(strategy_name, client_datasets, tinyprop_params)
        partition_results[strategy_name] = {
            'model': model,
            'metrics': metrics
        }
        print(f"Completed training for {strategy_name.upper()}")
    except Exception as e:
        print(f"Error in {strategy_name.upper()}: {str(e)}")
        continue
# Out:
# Starting training for NONIID partition...
#
# Training on partition: NONIID
#
# Round 1/100
# [Debug] Round 0 loss threshold: 0.1000
# [Debug] Round 0 loss threshold: 0.1000
# [Debug] Round 0 loss threshold: 0.1000
# [Debug] Round 0 loss threshold: 0.1000
# [Debug] Round 0 loss threshold: 0.1000
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Batch 5] Debug Info:
#   - Loss: 2.3100
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.2000
#   - Current phi_k: 0.4580
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 10] Debug Info:
#   - Loss: 2.2999
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2285
#   - Current phi_k: 0.6958
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 15] Debug Info:
#   - Loss: 2.2994
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2332
#   - Current phi_k: 0.9345
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 20] Debug Info:
#   - Loss: 2.2854
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2296
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 25] Debug Info:
#   - Loss: 2.2815
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2167
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1600
#   - Should Skip: False
#
# [Batch 30] Debug Info:
#   - Loss: 2.2734
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2191
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1333
#   - Should Skip: False
#
# [Batch 35] Debug Info:
#   - Loss: 2.2880
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2082
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1143
#   - Should Skip: False
#
# [Batch 40] Debug Info:
#   - Loss: 2.2639
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2060
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1000
#   - Should Skip: False
#
# [Batch 45] Debug Info:
#   - Loss: 2.2685
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1942
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0889
#   - Should Skip: False
#
# [Batch 50] Debug Info:
#   - Loss: 2.2568
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1967
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0800
#   - Should Skip: False
#
# [Batch 55] Debug Info:
#   - Loss: 2.2541
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1897
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0727
#   - Should Skip: False
#
# [Batch 60] Debug Info:
#   - Loss: 2.2826
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1874
#   - Current phi_k: 0.9989
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0667
#   - Should Skip: False
#
# [Batch 65] Debug Info:
#   - Loss: 2.2433
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1893
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0615
#   - Should Skip: False
#
# [Batch 70] Debug Info:
#   - Loss: 2.2536
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1791
#   - Current phi_k: 0.9996
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0571
#   - Should Skip: False
#
# [Batch 75] Debug Info:
#   - Loss: 2.2486
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1827
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0533
#   - Should Skip: False
#
# [Batch 80] Debug Info:
#   - Loss: 2.2416
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1812
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0500
#   - Should Skip: False
#
# [Batch 85] Debug Info:
#   - Loss: 2.2415
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1692
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0471
#   - Should Skip: False
#
# [Batch 90] Debug Info:
#   - Loss: 2.2260
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1704
#   - Current phi_k: 0.9998
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0444
#   - Should Skip: False
#
# [Batch 95] Debug Info:
#   - Loss: 2.2457
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1665
#   - Current phi_k: 0.9993
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0421
#   - Should Skip: False
#
# [Batch 100] Debug Info:
#   - Loss: 2.2164
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1572
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0400
#   - Should Skip: False
#
# [Batch 105] Debug Info:
#   - Loss: 2.2261
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1621
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0381
#   - Should Skip: False
#
# [Batch 110] Debug Info:
#   - Loss: 2.2221
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1550
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0364
#   - Should Skip: False
#
# [Batch 115] Debug Info:
#   - Loss: 2.2124
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1528
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0348
#   - Should Skip: False
#
# [Batch 120] Debug Info:
#   - Loss: 2.1980
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1461
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0333
#   - Should Skip: False
#
# [Batch 125] Debug Info:
#   - Loss: 2.2210
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1367
#   - Current phi_k: 0.9993
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0320
#   - Should Skip: False
#
# [Batch 130] Debug Info:
#   - Loss: 2.2019
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1508
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0308
#   - Should Skip: False
#
# [Batch 135] Debug Info:
#   - Loss: 2.2070
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1386
#   - Current phi_k: 0.9998
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0296
#   - Should Skip: False
#
# [Batch 140] Debug Info:
#   - Loss: 2.1830
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1417
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0286
#   - Should Skip: False
#
# [Batch 145] Debug Info:
#   - Loss: 2.1825
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1311
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0276
#   - Should Skip: False
#
# [Batch 150] Debug Info:
#   - Loss: 2.1928
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1272
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0267
#   - Should Skip: False
#
# [Batch 155] Debug Info:
#   - Loss: 2.1831
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1192
#   - Current phi_k: 0.9997
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0258
#   - Should Skip: False
#
# [Batch 160] Debug Info:
#   - Loss: 2.1909
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1146
#   - Current phi_k: 0.9991
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0250
#   - Should Skip: False
#
# [Batch 165] Debug Info:
#   - Loss: 2.1910
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1198
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0242
#   - Should Skip: False
#
# [Batch 170] Debug Info:
#   - Loss: 2.1656
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1160
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0235
#   - Should Skip: False
#
# [Batch 175] Debug Info:
#   - Loss: 2.1495
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1043
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0229
#   - Should Skip: False
#
# [Batch 180] Debug Info:
#   - Loss: 2.1321
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0941
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0222
#   - Should Skip: False
#
# [Batch 185] Debug Info:
#   - Loss: 2.1713
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0882
#   - Current phi_k: 0.9995
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0216
#   - Should Skip: False
#
# [Batch 190] Debug Info:
#   - Loss: 2.1577
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1049
#   - Current phi_k: 0.9998
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0211
#   - Should Skip: False
#
# [Batch 195] Debug Info:
#   - Loss: 2.1584
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0880
#   - Current phi_k: 0.9993
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0205
#   - Should Skip: False
#
# [Batch 200] Debug Info:
#   - Loss: 2.1609
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0868
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0200
#   - Should Skip: False
#
# [Batch 205] Debug Info:
#   - Loss: 2.1496
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0789
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0195
#   - Should Skip: False
#
# [Batch 210] Debug Info:
#   - Loss: 2.1098
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0759
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0190
#   - Should Skip: False
#
# [Batch 215] Debug Info:
#   - Loss: 2.1496
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0692
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0186
#   - Should Skip: False
#
# [Batch 220] Debug Info:
#   - Loss: 2.1213
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0646
#   - Current phi_k: 0.9998
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0182
#   - Should Skip: False
#
# [Batch 225] Debug Info:
#   - Loss: 2.1278
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0565
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0178
#   - Should Skip: False
#
# [Batch 230] Debug Info:
#   - Loss: 2.0990
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0641
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0174
#   - Should Skip: False
#
# [Batch 235] Debug Info:
#   - Loss: 2.0936
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0502
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0170
#   - Should Skip: False
#
# [Batch 240] Debug Info:
#   - Loss: 2.0992
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0187
#   - Current phi_k: 0.9978
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0167
#   - Should Skip: False
#
# [Batch 245] Debug Info:
#   - Loss: 2.0469
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0186
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0163
#   - Should Skip: False
#
# [Batch 250] Debug Info:
#   - Loss: 2.0856
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0119
#   - Current phi_k: 0.9974
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0160
#   - Should Skip: False
#
# [Batch 255] Debug Info:
#   - Loss: 2.0646
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0125
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0157
#   - Should Skip: False
#
# [Batch 260] Debug Info:
#   - Loss: 2.0681
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0103
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0154
#   - Should Skip: False
#
# [Batch 265] Debug Info:
#   - Loss: 2.0810
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9764
#   - Current phi_k: 0.9974
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0151
#   - Should Skip: False
#
# [Batch 270] Debug Info:
#   - Loss: 2.1058
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0073
#   - Current phi_k: 0.9973
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0148
#   - Should Skip: False
#
# [Batch 275] Debug Info:
#   - Loss: 2.0640
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9849
#   - Current phi_k: 0.9976
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0145
#   - Should Skip: False
#
# [Batch 280] Debug Info:
#   - Loss: 2.0312
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9759
#   - Current phi_k: 0.9990
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0143
#   - Should Skip: False
#
# [Batch 285] Debug Info:
#   - Loss: 1.9625
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9719
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0140
#   - Should Skip: False
#
# [Batch 290] Debug Info:
#   - Loss: 2.0096
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9225
#   - Current phi_k: 0.9987
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0138
#   - Should Skip: False
#
# [Batch 295] Debug Info:
#   - Loss: 1.9823
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9590
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0136
#   - Should Skip: False
#
# [Batch 300] Debug Info:
#   - Loss: 1.9815
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9114
#   - Current phi_k: 0.9988
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0133
#   - Should Skip: False
#
# [Batch 305] Debug Info:
#   - Loss: 1.9342
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9172
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0131
#   - Should Skip: False
#
# [Batch 310] Debug Info:
#   - Loss: 1.8948
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8814
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0129
#   - Should Skip: False
#
# [Batch 315] Debug Info:
#   - Loss: 1.9135
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8570
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0127
#   - Should Skip: False
#
# [Batch 320] Debug Info:
#   - Loss: 1.9026
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8677
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0125
#   - Should Skip: False
#
# [Batch 325] Debug Info:
#   - Loss: 1.9056
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8429
#   - Current phi_k: 0.9971
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0123
#   - Should Skip: False
#
# [Batch 330] Debug Info:
#   - Loss: 1.8689
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8685
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0121
#   - Should Skip: False
#
# [Batch 335] Debug Info:
#   - Loss: 1.8619
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8230
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0119
#   - Should Skip: False
#
# [Batch 340] Debug Info:
#   - Loss: 1.8892
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8065
#   - Current phi_k: 0.9965
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0118
#   - Should Skip: False
#
# [Batch 345] Debug Info:
#   - Loss: 1.7981
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7892
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0116
#   - Should Skip: False
#
# [Batch 350] Debug Info:
#   - Loss: 1.8029
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7836
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0114
#   - Should Skip: False
#
# [Batch 355] Debug Info:
#   - Loss: 1.8276
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7378
#   - Current phi_k: 0.9971
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0113
#   - Should Skip: False
#
# [Batch 360] Debug Info:
#   - Loss: 1.7422
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7350
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0111
#   - Should Skip: False
#
# [Batch 365] Debug Info:
#   - Loss: 1.7461
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7317
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0110
#   - Should Skip: False
#
# [Batch 370] Debug Info:
#   - Loss: 1.7781
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.6827
#   - Current phi_k: 0.9976
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0108
#   - Should Skip: False
#
# [Batch 375] Debug Info:
#   - Loss: 1.8331
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.6731
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0133
#   - Should Skip: False
#
# [Batch 380] Debug Info:
#   - Loss: 1.7524
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.6943
#   - Current phi_k: 0.9973
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0132
#   - Should Skip: False
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Batch 5] Debug Info:
#   - Loss: 2.3031
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.2000
#   - Current phi_k: 0.3794
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 10] Debug Info:
#   - Loss: 2.2969
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2320
#   - Current phi_k: 0.6975
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 15] Debug Info:
#   - Loss: 2.2937
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2288
#   - Current phi_k: 0.9370
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 20] Debug Info:
#   - Loss: 2.2918
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2205
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1500
#   - Should Skip: False
#
# [Batch 25] Debug Info:
#   - Loss: 2.2906
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2201
#   - Current phi_k: 0.9998
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1200
#   - Should Skip: False
#
# [Batch 30] Debug Info:
#   - Loss: 2.2759
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2194
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1000
#   - Should Skip: False
#
# [Batch 35] Debug Info:
#   - Loss: 2.2819
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2085
#   - Current phi_k: 0.9995
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0857
#   - Should Skip: False
#
# [Batch 40] Debug Info:
#   - Loss: 2.2650
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2096
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0750
#   - Should Skip: False
#
# [Batch 45] Debug Info:
#   - Loss: 2.2746
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2002
#   - Current phi_k: 0.9997
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0667
#   - Should Skip: False
#
# [Batch 50] Debug Info:
#   - Loss: 2.2675
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2038
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0600
#   - Should Skip: False
#
# [Batch 55] Debug Info:
#   - Loss: 2.2563
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1984
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0545
#   - Should Skip: False
#
# [Batch 60] Debug Info:
#   - Loss: 2.2603
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1952
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0500
#   - Should Skip: False
#
# [Batch 65] Debug Info:
#   - Loss: 2.2651
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1906
#   - Current phi_k: 0.9997
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0462
#   - Should Skip: False
#
# [Batch 70] Debug Info:
#   - Loss: 2.2625
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1924
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0429
#   - Should Skip: False
#
# [Batch 75] Debug Info:
#   - Loss: 2.2497
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1872
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0400
#   - Should Skip: False
#
# [Batch 80] Debug Info:
#   - Loss: 2.2363
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1800
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0375
#   - Should Skip: False
#
# [Batch 85] Debug Info:
#   - Loss: 2.2286
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1794
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0353
#   - Should Skip: False
#
# [Batch 90] Debug Info:
#   - Loss: 2.2497
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1635
#   - Current phi_k: 0.9992
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0333
#   - Should Skip: False
#
# [Batch 95] Debug Info:
#   - Loss: 2.2247
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1681
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0316
#   - Should Skip: False
#
# [Batch 100] Debug Info:
#   - Loss: 2.2323
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1681
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0300
#   - Should Skip: False
#
# [Batch 105] Debug Info:
#   - Loss: 2.2329
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1644
#   - Current phi_k: 0.9997
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0286
#   - Should Skip: False
#
# [Batch 110] Debug Info:
#   - Loss: 2.2124
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1584
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0273
#   - Should Skip: False
#
# [Batch 115] Debug Info:
#   - Loss: 2.2266
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1536
#   - Current phi_k: 0.9993
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0261
#   - Should Skip: False
#
# [Batch 120] Debug Info:
#   - Loss: 2.2038
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1603
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0250
#   - Should Skip: False
#
# [Batch 125] Debug Info:
#   - Loss: 2.2153
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1497
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0240
#   - Should Skip: False
#
# [Batch 130] Debug Info:
#   - Loss: 2.2307
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1479
#   - Current phi_k: 0.9990
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0231
#   - Should Skip: False
#
# [Batch 135] Debug Info:
#   - Loss: 2.1857
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1486
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0222
#   - Should Skip: False
#
# [Batch 140] Debug Info:
#   - Loss: 2.1958
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1435
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0214
#   - Should Skip: False
#
# [Batch 145] Debug Info:
#   - Loss: 2.2162
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1282
#   - Current phi_k: 0.9988
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0207
#   - Should Skip: False
#
# [Batch 150] Debug Info:
#   - Loss: 2.1928
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1384
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0200
#   - Should Skip: False
#
# [Batch 155] Debug Info:
#   - Loss: 2.1807
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1312
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0194
#   - Should Skip: False
#
# [Batch 160] Debug Info:
#   - Loss: 2.2092
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1217
#   - Current phi_k: 0.9987
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0187
#   - Should Skip: False
#
# [Batch 165] Debug Info:
#   - Loss: 2.1925
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1274
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0182
#   - Should Skip: False
#
# [Batch 170] Debug Info:
#   - Loss: 2.1934
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1172
#   - Current phi_k: 0.9987
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0176
#   - Should Skip: False
#
# [Batch 175] Debug Info:
#   - Loss: 2.1928
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1166
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0171
#   - Should Skip: False
#
# [Batch 180] Debug Info:
#   - Loss: 2.1803
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1171
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0167
#   - Should Skip: False
#
# [Batch 185] Debug Info:
#   - Loss: 2.1827
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0922
#   - Current phi_k: 0.9985
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0162
#   - Should Skip: False
#
# [Batch 190] Debug Info:
#   - Loss: 2.1616
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1020
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0158
#   - Should Skip: False
#
# [Batch 195] Debug Info:
#   - Loss: 2.1767
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0925
#   - Current phi_k: 0.9987
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0154
#   - Should Skip: False
#
# [Batch 200] Debug Info:
#   - Loss: 2.1445
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1028
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0150
#   - Should Skip: False
#
# [Batch 205] Debug Info:
#   - Loss: 2.1270
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0791
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0146
#   - Should Skip: False
#
# [Batch 210] Debug Info:
#   - Loss: 2.0984
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0633
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0143
#   - Should Skip: False
#
# [Batch 215] Debug Info:
#   - Loss: 2.1133
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0653
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0140
#   - Should Skip: False
#
# [Batch 220] Debug Info:
#   - Loss: 2.1336
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0645
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0136
#   - Should Skip: False
#
# [Batch 225] Debug Info:
#   - Loss: 2.1303
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0464
#   - Current phi_k: 0.9980
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0133
#   - Should Skip: False
#
# [Batch 230] Debug Info:
#   - Loss: 2.1623
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0569
#   - Current phi_k: 0.9975
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0130
#   - Should Skip: False
#
# [Batch 235] Debug Info:
#   - Loss: 2.1080
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0634
#   - Current phi_k: 0.9992
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0128
#   - Should Skip: False
#
# [Batch 240] Debug Info:
#   - Loss: 2.1263
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0311
#   - Current phi_k: 0.9985
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0125
#   - Should Skip: False
#
# [Batch 245] Debug Info:
#   - Loss: 2.1307
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0436
#   - Current phi_k: 0.9983
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0122
#   - Should Skip: False
#
# [Batch 250] Debug Info:
#   - Loss: 2.1081
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0332
#   - Current phi_k: 0.9981
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0120
#   - Should Skip: False
#
# [Batch 255] Debug Info:
#   - Loss: 2.0686
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0269
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0118
#   - Should Skip: False
#
# [Batch 260] Debug Info:
#   - Loss: 2.0831
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0158
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0115
#   - Should Skip: False
#
# [Batch 265] Debug Info:
#   - Loss: 2.0114
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.0011
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0113
#   - Should Skip: False
#
# [Batch 270] Debug Info:
#   - Loss: 2.0224
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9952
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0111
#   - Should Skip: False
#
# [Batch 275] Debug Info:
#   - Loss: 1.9818
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9690
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0109
#   - Should Skip: False
#
# [Batch 280] Debug Info:
#   - Loss: 1.9769
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9603
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0107
#   - Should Skip: False
#
# [Batch 285] Debug Info:
#   - Loss: 2.0055
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9304
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0105
#   - Should Skip: False
#
# [Batch 290] Debug Info:
#   - Loss: 1.9478
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9488
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0103
#   - Should Skip: False
#
# [Batch 295] Debug Info:
#   - Loss: 1.9798
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.9264
#   - Current phi_k: 0.9992
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0102
#   - Should Skip: False
#
# [Batch 300] Debug Info:
#   - Loss: 1.9526
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8861
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0100
#   - Should Skip: False
#
# [Batch 305] Debug Info:
#   - Loss: 1.9339
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8993
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0098
#   - Should Skip: False
#
# [Batch 310] Debug Info:
#   - Loss: 1.9208
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8629
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0097
#   - Should Skip: False
#
# [Batch 315] Debug Info:
#   - Loss: 1.8474
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8620
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0095
#   - Should Skip: False
#
# [Batch 320] Debug Info:
#   - Loss: 2.0034
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8396
#   - Current phi_k: 0.9951
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0094
#   - Should Skip: False
#
# [Batch 325] Debug Info:
#   - Loss: 1.8807
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8840
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0092
#   - Should Skip: False
#
# [Batch 330] Debug Info:
#   - Loss: 1.8946
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8077
#   - Current phi_k: 0.9972
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0091
#   - Should Skip: False
#
# [Batch 335] Debug Info:
#   - Loss: 1.8725
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7763
#   - Current phi_k: 0.9980
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0090
#   - Should Skip: False
#
# [Batch 340] Debug Info:
#   - Loss: 1.9665
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8007
#   - Current phi_k: 0.9930
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0088
#   - Should Skip: False
#
# [Batch 345] Debug Info:
#   - Loss: 1.7825
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.8268
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0087
#   - Should Skip: False
#
# [Batch 350] Debug Info:
#   - Loss: 1.7826
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7552
#   - Current phi_k: 0.9993
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0086
#   - Should Skip: False
#
# [Batch 355] Debug Info:
#   - Loss: 1.7373
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7405
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0085
#   - Should Skip: False
#
# [Batch 360] Debug Info:
#   - Loss: 1.8043
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.7199
#   - Current phi_k: 0.9990
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0083
#   - Should Skip: False
#
# [Batch 365] Debug Info:
#   - Loss: 1.7199
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.6730
#   - Current phi_k: 0.9969
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0082
#   - Should Skip: False
#
# [Batch 370] Debug Info:
#   - Loss: 1.7260
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 1.6623
#   - Current phi_k: 0.9961
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0081
#   - Should Skip: False
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Batch 5] Debug Info:
#   - Loss: 2.2945
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.2000
#   - Current phi_k: 0.4582
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 10] Debug Info:
#   - Loss: 2.2867
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2322
#   - Current phi_k: 0.6966
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 15] Debug Info:
#   - Loss: 2.2978
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2238
#   - Current phi_k: 0.7737
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 20] Debug Info:
#   - Loss: 2.2966
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2234
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.2000
#   - Should Skip: False
#
# [Batch 25] Debug Info:
#   - Loss: 2.2808
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2257
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1600
#   - Should Skip: False
#
# [Batch 30] Debug Info:
#   - Loss: 2.2673
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2204
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1333
#   - Should Skip: False
#
# [Batch 35] Debug Info:
#   - Loss: 2.2833
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2059
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1143
#   - Should Skip: False
#
# [Batch 40] Debug Info:
#   - Loss: 2.2655
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.2062
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.1000
#   - Should Skip: False
#
# [Batch 45] Debug Info:
#   - Loss: 2.2636
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1986
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0889
#   - Should Skip: False
#
# [Batch 50] Debug Info:
#   - Loss: 2.2640
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1975
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0800
#   - Should Skip: False
#
# [Batch 55] Debug Info:
#   - Loss: 2.2636
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1907
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0727
#   - Should Skip: False
#
# [Batch 60] Debug Info:
#   - Loss: 2.2610
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1867
#   - Current phi_k: 0.9995
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0667
#   - Should Skip: False
#
# [Batch 65] Debug Info:
#   - Loss: 2.2591
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1884
#   - Current phi_k: 0.9999
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0615
#   - Should Skip: False
#
# [Batch 70] Debug Info:
#   - Loss: 2.2425
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1814
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0571
#   - Should Skip: False
#
# [Batch 75] Debug Info:
#   - Loss: 2.2482
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 2.1775
#   - Current phi_k: 0.9996
#   - Current phi_max: 0.9900
#   - Layer Sparsity: 0.5000
#   - Skip Ratio: 0.2000
#   - Current Skip Ratio: 0.0533
#   - Should Skip: False
#
# [Batch 80] Debug Info:
#   - Loss: 2.2441
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
# ...
#   - Should Skip: False
#
# [Batch 1615] Debug Info:
#   - Loss: 0.8177
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8290
#   - Current phi_k: 0.9990
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5994
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0285
#   - Should Skip: False
#
# [Batch 1620] Debug Info:
#   - Loss: 0.9892
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7754
#   - Current phi_k: 0.9770
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5862
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0290
#   - Should Skip: True
#
# [Batch 1625] Debug Info:
#   - Loss: 0.7911
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8465
#   - Current phi_k: 0.9934
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5961
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0295
#   - Should Skip: True
#
# [Batch 1630] Debug Info:
#   - Loss: 1.2303
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8984
#   - Current phi_k: 0.9723
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5834
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0313
#   - Should Skip: True
#
# [Batch 1635] Debug Info:
#   - Loss: 0.9234
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.9451
#   - Current phi_k: 0.9916
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5949
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0318
#   - Should Skip: True
#
# [Batch 1640] Debug Info:
#   - Loss: 0.9780
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8524
#   - Current phi_k: 0.9722
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5833
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0341
#   - Should Skip: True
#
# [Batch 1645] Debug Info:
#   - Loss: 0.7716
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8699
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0347
#   - Should Skip: False
#
# [Batch 1650] Debug Info:
#   - Loss: 0.8945
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8318
#   - Current phi_k: 0.9920
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5952
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0364
#   - Should Skip: True
#
# [Batch 1655] Debug Info:
#   - Loss: 0.8100
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7895
#   - Current phi_k: 0.9977
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5986
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0369
#   - Should Skip: False
#
# [Batch 1660] Debug Info:
#   - Loss: 0.8057
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8388
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0380
#   - Should Skip: False
#
# [Batch 1665] Debug Info:
#   - Loss: 0.8688
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8840
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0384
#   - Should Skip: False
#
# [Batch 1670] Debug Info:
#   - Loss: 0.7931
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8414
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0389
#   - Should Skip: False
#
# [Batch 1675] Debug Info:
#   - Loss: 0.9222
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8455
#   - Current phi_k: 0.9991
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5995
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0394
#   - Should Skip: False
#
# [Batch 1680] Debug Info:
#   - Loss: 0.9846
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8345
#   - Current phi_k: 0.9903
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5942
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0405
#   - Should Skip: True
#
# [Batch 1685] Debug Info:
#   - Loss: 0.8204
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8099
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0409
#   - Should Skip: False
#
# [Batch 1690] Debug Info:
#   - Loss: 0.7705
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7948
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0414
#   - Should Skip: False
#
# [Batch 1695] Debug Info:
#   - Loss: 0.9376
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7965
#   - Current phi_k: 0.9826
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5895
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0431
#   - Should Skip: True
#
# [Batch 1700] Debug Info:
#   - Loss: 0.8462
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8599
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0435
#   - Should Skip: False
#
# [Batch 1705] Debug Info:
#   - Loss: 0.8173
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8046
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0452
#   - Should Skip: False
#
# [Batch 1710] Debug Info:
#   - Loss: 0.9147
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8722
#   - Current phi_k: 0.9915
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5949
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0462
#   - Should Skip: True
#
# [Batch 1715] Debug Info:
#   - Loss: 0.7521
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8461
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0466
#   - Should Skip: False
#
# [Batch 1720] Debug Info:
#   - Loss: 0.7806
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8177
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0477
#   - Should Skip: False
#
# [Batch 1725] Debug Info:
#   - Loss: 0.8614
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7756
#   - Current phi_k: 0.9901
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5941
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0487
#   - Should Skip: True
#
# [Batch 1730] Debug Info:
#   - Loss: 0.8281
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7923
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5996
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0491
#   - Should Skip: False
#
# [Batch 1735] Debug Info:
#   - Loss: 0.7776
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8167
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0496
#   - Should Skip: False
#
# [Batch 1740] Debug Info:
#   - Loss: 0.9246
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8407
#   - Current phi_k: 0.9905
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5943
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0511
#   - Should Skip: True
#
# [Batch 1745] Debug Info:
#   - Loss: 0.7661
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8198
#   - Current phi_k: 0.9994
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5996
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0516
#   - Should Skip: False
#
# [Batch 1750] Debug Info:
#   - Loss: 0.9475
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8859
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0526
#   - Should Skip: False
#
# [Batch 1755] Debug Info:
#   - Loss: 0.7751
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8763
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0530
#   - Should Skip: False
#
# [Batch 1760] Debug Info:
#   - Loss: 0.8182
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8272
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0540
#   - Should Skip: False
#
# [Batch 1765] Debug Info:
#   - Loss: 0.9131
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8100
#   - Current phi_k: 0.9951
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5971
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0544
#   - Should Skip: False
#
# [Batch 1770] Debug Info:
#   - Loss: 0.8687
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8689
#   - Current phi_k: 0.9906
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5943
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0554
#   - Should Skip: True
#
# [Batch 1775] Debug Info:
#   - Loss: 0.9033
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.9171
#   - Current phi_k: 0.9866
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5920
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0569
#   - Should Skip: True
#
# [Batch 1780] Debug Info:
#   - Loss: 0.8075
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8543
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0573
#   - Should Skip: False
#
# [Batch 1785] Debug Info:
#   - Loss: 0.8978
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7749
#   - Current phi_k: 0.9865
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5919
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0588
#   - Should Skip: True
#
# [Batch 1790] Debug Info:
#   - Loss: 0.8049
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8219
#   - Current phi_k: 0.9980
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.5988
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0598
#   - Should Skip: False
#
# [Batch 1795] Debug Info:
#   - Loss: 0.8508
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8654
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0607
#   - Should Skip: False
#
# [Batch 1800] Debug Info:
#   - Loss: 0.7827
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.8279
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0617
#   - Should Skip: False
#
# [Batch 1805] Debug Info:
#   - Loss: 0.8582
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7669
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0626
#   - Should Skip: False
#
# [Batch 1810] Debug Info:
#   - Loss: 0.7816
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.9072
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0635
#   - Should Skip: False
#
# [Batch 1815] Debug Info:
#   - Loss: 0.7163
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7336
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0645
#   - Should Skip: False
#
# [Batch 1820] Debug Info:
#   - Loss: 0.7257
#   - Loss Change: 0.0000
#   - Relative Loss Change: 0.0000
#   - Dynamic Threshold: 0.7832
#   - Current phi_k: 1.0000
#   - Current phi_max: 0.9940
#   - Layer Sparsity: 0.6000
#   - Skip Ratio: 0.6000
#   - Current Skip Ratio: 0.0659
#   - Should Skip: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 45
#      43 print(f"\nStarting training for {strategy_name.upper()} partition...")
#      44 try:
# ---> 45     model, metrics = train_and_analyze_partition(strategy_name, client_datasets, tinyprop_params)
#      46     partition_results[strategy_name] = {
#      47         'model': model,
#      48         'metrics': metrics
#      49     }
#      50     print(f"Completed training for {strategy_name.upper()}")
#
# Cell In[8], line 9, in train_and_analyze_partition(partition_name, client_datasets, tinyprop_params)
#       6 config = get_tinyprop_config('mnist')
#       8 # Run training
# ----> 9 model, metrics = federated_training(
#      10     client_datasets=client_datasets,
#      11     model_name='mnist',
#      12     testset=testset,
#      13     tinyprop_params=tinyprop_params,
#      14     aggregator_fn=sparse_fedavg_aggregate,
#      15     rounds=100,
#      16     device="cuda" if torch.cuda.is_available() else "cpu",
#      17     local_epochs=1,
#      18     early_stopping_patience=100,
#      19     early_stopping_delta=0.001,
#      20     csv_log_path=f'results/mnist_metrics.csv',  # Single CSV file for all partitions
#      21     initial_sparsity=tinyprop_params.S_min,
#      22     target_sparsity=tinyprop_params.S_max,
#      23     energy_budget=1000,
#      24     save_dir='results',
#      25     save_interval=1,
#      26     use_dense_baseline=False
#      27 )
#      29 # Print summary statistics
#      30 print(f"\nTraining Summary for {partition_name.upper()}:")
#
# File c:\Users\la7tim\Desktop\Internship\FedTinyProp\clients\federated_training.py:329, in federated_training(client_datasets, model_name, testset, tinyprop_params, aggregator_fn, aggregator_kwargs, rounds, device, local_epochs, early_stopping_patience, early_stopping_delta, csv_log_path, initial_sparsity, target_sparsity, energy_budget, num_clients, num_rounds, partition_type, alpha, seed, save_dir, save_interval, quantization_bits, use_dense_baseline)
#     327 # Client training phase
#     328 for client_idx, client in enumerate(clients):
# --> 329     parameters, num_examples, metrics = client.fit(
#     330         [val.cpu().numpy() for val in global_params.values()],
#     331         config={"local_epochs": local_epochs}
#     332     )
#     334     client_deltas.append(client.weight_deltas)
#     336     # Update statistics from client metrics
#
# File c:\Users\la7tim\Desktop\Internship\FedTinyProp\clients\federated_client.py:203, in FederatedClient.fit(self, parameters, config)
#     200 batch_size = config.get("batch_size", 32) if config else 32
#     201 local_epochs = config.get("local_epochs", 1) if config else 1
# --> 203 loss, accuracy = self.train(num_epochs=local_epochs, batch_size=batch_size)
#     204 updated_parameters = self.get_parameters()
#     205 metrics = {
#     206     "loss": float(loss),
#     207     "accuracy": float(accuracy),
#    (...)
#     210     "sparsity": self.last_sparsity
#     211 }
#
# File c:\Users\la7tim\Desktop\Internship\FedTinyProp\clients\federated_client.py:666, in FederatedClient.train(self, num_epochs, batch_size)
#     664 if self.adaptive_sparsity:
#     665     phi = self.update_adaptive_sparsity(grad_norm)
# --> 666     self.apply_gradient_sparsification(phi)
#     667     base_sparsity = self.S_min + (self.S_max - self.S_min) * (1 - phi)
#     668     local_sparsity = min(self.S_max, base_sparsity * progressive_factor)
#
# File c:\Users\la7tim\Desktop\Internship\FedTinyProp\clients\federated_client.py:277, in FederatedClient.apply_gradient_sparsification(self, phi)
#     275 # Get top-k values and indices
#     276 grad_flat = param.grad.data.view(-1)
# --> 277 values, indices = torch.topk(torch.abs(grad_flat), k=num_keep)
#     279 # Create sparse gradient
#     280 sparse_grad = torch.zeros_like(grad_flat)
#
# KeyboardInterrupt:
