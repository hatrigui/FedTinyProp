# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
print("Project root added to sys.path")
# Out:
# Project root added to sys.path

# %%
import torch
import torch.nn 
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import os

from clients.federated_training import federated_training
from utils.data_partition import dirichlet_partition


torch.manual_seed(42)
np.random.seed(42)

# %%
import os

# Create results directory in the notebook directory
os.makedirs("results", exist_ok=True)
print("Results directory created at:", os.path.abspath("results"))
# Out:
# Results directory created at: c:\Users\la7tim\Desktop\Internship\FedTinyProp\notebooks\results

# %%
transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    
    
trainset = datasets.MNIST('./data', train=True, download=True, transform=transform)
testset = datasets.MNIST('./data', train=False, transform=transform)
    
    

print(f"Training set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
print(f"Number of classes: {len(trainset.classes)}")
# Out:
# Training set size: 60000
# Test set size: 10000
# Number of classes: 10

# %%
num_clients = 5
partitions = {
    "noniid":   dirichlet_partition(trainset, num_clients=num_clients, alpha=0.01),
}
# Out:
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\data_partition.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   labels = np.array(dataset.targets)

# %%
from utils.partitions_visualization import print_partition_stats, plot_data_distribution

# Print detailed statistics
print_partition_stats(partitions, "MNIST")

# Create comprehensive visualization
fig = plot_data_distribution(partitions, "MNIST")
plt.show()
# Out:
# === Partition Statistics for MNIST ===
#
# NONIID Partition:
# Total samples: 60000
#
# Per-client distribution:
# Client 0: 18057 samples (30.09%)
# Client 1: 11340 samples (18.90%)
# Client 2: 12593 samples (20.99%)
# Client 3: 12076 samples (20.13%)
# Client 4: 5934 samples (9.89%)
# [Debug] Number of classes: 10
# [Debug] Number of clients: 5
# [Debug] Processing client 0 with 18057 samples
# [Debug] Client 0 has 18057 valid targets
# [Debug] Client 0 class counts: [1.000e+00 1.000e+00 5.953e+03 1.000e+00 5.837e+03 1.000e+00 1.000e+00
#  6.260e+03 1.000e+00 1.000e+00]
# [Debug] Processing client 1 with 11340 samples
# [Debug] Client 1 has 11340 valid targets
# [Debug] Client 1 class counts: [1.000e+00 1.000e+00 1.000e+00 3.000e+00 1.000e+00 5.417e+03 5.913e+03
#  1.000e+00 1.000e+00 1.000e+00]
# [Debug] Processing client 2 with 12593 samples
# [Debug] Client 2 has 12593 valid targets
# [Debug] Client 2 class counts: [1.000e+00 6.738e+03 1.000e+00 1.000e+00 2.000e+00 1.000e+00 1.000e+00
#  1.000e+00 5.846e+03 1.000e+00]
# [Debug] Processing client 3 with 12076 samples
# [Debug] Client 3 has 12076 valid targets
# [Debug] Client 3 class counts: [1.000e+00 1.000e+00 1.000e+00 6.125e+03 1.000e+00 1.000e+00 1.000e+00
#  1.000e+00 1.000e+00 5.943e+03]
# [Debug] Processing client 4 with 5934 samples
# [Debug] Client 4 has 5934 valid targets
# [Debug] Client 4 class counts: [5.919e+03 1.000e+00 2.000e+00 1.000e+00 1.000e+00 1.000e+00 2.000e+00
#  2.000e+00 2.000e+00 3.000e+00]
# c:\Users\la7tim\Desktop\Internship\FedTinyProp\utils\partitions_visualization.py:17: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   targets = np.array(partitions[0].dataset.targets)

# %%
from models.config import get_tinyprop_config

config = get_tinyprop_config("mnist")
config['quantization_bits'] = 8  # Explicit for clarity

print("\nModel Configuration:")
for key, value in config.items():
    print(f"{key}: {value}")

tinyprop_params = config["tinyprop_params"]
print("\nTinyProp Parameters:")
print(f"S_min: {tinyprop_params.S_min}")
print(f"S_max: {tinyprop_params.S_max}")
print(f"zeta: {tinyprop_params.zeta}")
print(f"number_of_layers: {tinyprop_params.number_of_layers}")
# Out:
# Model Configuration:
# tinyprop_params: <models.tinyProp.TinyPropParams object at 0x000001BDC4A55950>
# optimizer: {'type': 'sgd', 'lr': 0.0005, 'momentum': 0.7, 'weight_decay': 0.0001}
# lr_scheduler: {'type': 'cosine', 'T_max': 100, 'eta_min': 1e-05, 'warmup_epochs': 5, 'warmup_start_lr': 1e-05}
# gradient_clip: 1.0
# batch_size: 32
# num_epochs: 1
# label_smoothing: 0.1
# quantization: {'bits': 8, 'enabled': True, 'adaptive': True, 'min_bits': 4, 'max_bits': 16, 'layer_specific': True, 'error_threshold': 0.01, 'momentum': 0.9}
# quantization_bits: 8
#
# TinyProp Parameters:
# S_min: 0.5
# S_max: 0.95
# zeta: 0.5
# number_of_layers: 4

# %%
from clients.aggregators import sparse_fedavg_aggregate
def train_and_analyze_partition(partition_name, client_datasets, tinyprop_params):
    print(f"\nTraining on partition: {partition_name.upper()}")
    
    # Get base config
    config = get_tinyprop_config('mnist')
    
    # Run training
    model, metrics = federated_training(
        client_datasets=client_datasets,
        model_name='mnist',
        testset=testset,
        tinyprop_params=tinyprop_params,
        aggregator_fn=sparse_fedavg_aggregate,
        rounds=100,
        device="cuda" if torch.cuda.is_available() else "cpu",
        local_epochs=1,
        early_stopping_patience=100,
        early_stopping_delta=0.001,
        csv_log_path=f'results/mnist_metrics.csv',  # Single CSV file for all partitions
        initial_sparsity=tinyprop_params.S_min,
        target_sparsity=tinyprop_params.S_max,
        energy_budget=1000,
        save_dir='results',
        save_interval=1,
        use_dense_baseline=True,
        use_fedprox= True,
        fedprox_mu= 0.01
    )
    
    # Print summary statistics
    print(f"\nTraining Summary for {partition_name.upper()}:")
    print(f"Final Accuracy: {metrics['accuracy'][-1]:.4f}")
    print(f"Average Sparsity: {np.mean(metrics['sparsity']):.4f}")
    print(f"Average Compression Ratio: {np.mean(metrics['compression_ratio']):.4f}")
    print(f"Average Effective Compute Ratio: {np.mean(metrics['effective_compute_ratio']):.4f}")
    print(f"Total Communication Cost: {metrics['communication'][-1]/1024:.2f} KB")
    print(f"Total Memory Saved: {metrics['memory_saved'][-1]:.2f} MB")
    
    return model, metrics

# Run training for each partition
partition_results = {}
for strategy_name, client_datasets in partitions.items():
    print(f"\nStarting training for {strategy_name.upper()} partition...")
    try:
        model, metrics = train_and_analyze_partition(strategy_name, client_datasets, tinyprop_params)
        partition_results[strategy_name] = {
            'model': model,
            'metrics': metrics
        }
        print(f"Completed training for {strategy_name.upper()}")
    except Exception as e:
        print(f"Error in {strategy_name.upper()}: {str(e)}")
        continue
# Out:
# Starting training for NONIID partition...
#
# Training on partition: NONIID
#
# [Training Debug] Initializing clients...
# [Training Debug] Client 0 initialized with 18057 samples
# [Training Debug] Client 1 initialized with 11340 samples
# [Training Debug] Client 2 initialized with 12593 samples
# [Training Debug] Client 3 initialized with 12076 samples
# [Training Debug] Client 4 initialized with 5934 samples
#
# Round 1/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 0 loss threshold: 0.1000
#
# [Server Debug] Starting aggregation of client updates...
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 4/1625866
# Dense updates: 36
# Sparse updates: 4
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31753.66KB
# Total communication: 63508.86KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 23.47KB
#   fc2.bias: 0.20KB
#
# [INFO] Updated metrics saved to results/mnist_metrics.csv
# [INFO] Appended round 1 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 1 Summary:
# Accuracy: 0.1940
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31753.66KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 2/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 1 loss threshold: 0.0970
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 1 loss threshold: 0.0970
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 1 loss threshold: 0.0970
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 1 loss threshold: 0.0970
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 1 loss threshold: 0.0970
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 2 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 2 Summary:
# Accuracy: 0.1950
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 3/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 2 loss threshold: 0.0941
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 2 loss threshold: 0.0941
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 2 loss threshold: 0.0941
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 2 loss threshold: 0.0941
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 2 loss threshold: 0.0941
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 3 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 3 Summary:
# Accuracy: 0.1953
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 4/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 3 loss threshold: 0.0913
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 3 loss threshold: 0.0913
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 3 loss threshold: 0.0913
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 3 loss threshold: 0.0913
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 3 loss threshold: 0.0913
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 4 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 4 Summary:
# Accuracy: 0.1958
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 5/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 4 loss threshold: 0.0885
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 4 loss threshold: 0.0885
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 4 loss threshold: 0.0885
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 4 loss threshold: 0.0885
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 4 loss threshold: 0.0885
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 5 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 5 Summary:
# Accuracy: 0.1999
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 6/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 5 loss threshold: 0.0859
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 5 loss threshold: 0.0859
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 5 loss threshold: 0.0859
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 5 loss threshold: 0.0859
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 5 loss threshold: 0.0859
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 6 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 6 Summary:
# Accuracy: 0.2057
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 7/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 6 loss threshold: 0.0833
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 6 loss threshold: 0.0833
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 6 loss threshold: 0.0833
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 6 loss threshold: 0.0833
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 6 loss threshold: 0.0833
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 7 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 7 Summary:
# Accuracy: 0.2103
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 8/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 7 loss threshold: 0.0808
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 7 loss threshold: 0.0808
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 7 loss threshold: 0.0808
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 7 loss threshold: 0.0808
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 7 loss threshold: 0.0808
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 8 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 8 Summary:
# Accuracy: 0.2143
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 9/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 8 loss threshold: 0.0784
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 8 loss threshold: 0.0784
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 8 loss threshold: 0.0784
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 8 loss threshold: 0.0784
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 8 loss threshold: 0.0784
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 9 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 9 Summary:
# Accuracy: 0.2135
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 10/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 9 loss threshold: 0.0760
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 9 loss threshold: 0.0760
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 9 loss threshold: 0.0760
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 9 loss threshold: 0.0760
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 9 loss threshold: 0.0760
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 10 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 10 Summary:
# Accuracy: 0.2136
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 11/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 10 loss threshold: 0.0737
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 10 loss threshold: 0.0737
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 10 loss threshold: 0.0737
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 10 loss threshold: 0.0737
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 10 loss threshold: 0.0737
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 11 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 11 Summary:
# Accuracy: 0.2121
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 12/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 11 loss threshold: 0.0715
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 11 loss threshold: 0.0715
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 11 loss threshold: 0.0715
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 11 loss threshold: 0.0715
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 11 loss threshold: 0.0715
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 12 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 12 Summary:
# Accuracy: 0.2145
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 13/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 12 loss threshold: 0.0694
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 12 loss threshold: 0.0694
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 12 loss threshold: 0.0694
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 12 loss threshold: 0.0694
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 12 loss threshold: 0.0694
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 13 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 13 Summary:
# Accuracy: 0.2128
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 14/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 13 loss threshold: 0.0673
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 13 loss threshold: 0.0673
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 13 loss threshold: 0.0673
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 13 loss threshold: 0.0673
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 13 loss threshold: 0.0673
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 14 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 14 Summary:
# Accuracy: 0.2123
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 15/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 14 loss threshold: 0.0653
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 14 loss threshold: 0.0653
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 14 loss threshold: 0.0653
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 14 loss threshold: 0.0653
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 14 loss threshold: 0.0653
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 15 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 15 Summary:
# Accuracy: 0.2126
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 16/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 15 loss threshold: 0.0633
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 15 loss threshold: 0.0633
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 15 loss threshold: 0.0633
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 15 loss threshold: 0.0633
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 15 loss threshold: 0.0633
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 16 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 16 Summary:
# Accuracy: 0.2132
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 17/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 16 loss threshold: 0.0614
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 16 loss threshold: 0.0614
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 16 loss threshold: 0.0614
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 16 loss threshold: 0.0614
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 16 loss threshold: 0.0614
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 17 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 17 Summary:
# Accuracy: 0.2115
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 18/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 17 loss threshold: 0.0596
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 17 loss threshold: 0.0596
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 17 loss threshold: 0.0596
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 17 loss threshold: 0.0596
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 17 loss threshold: 0.0596
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 18 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 18 Summary:
# Accuracy: 0.2116
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 19/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 18 loss threshold: 0.0578
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 18 loss threshold: 0.0578
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 18 loss threshold: 0.0578
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 18 loss threshold: 0.0578
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 18 loss threshold: 0.0578
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 19 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 19 Summary:
# Accuracy: 0.2131
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 20/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 19 loss threshold: 0.0561
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 19 loss threshold: 0.0561
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 19 loss threshold: 0.0561
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 19 loss threshold: 0.0561
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 19 loss threshold: 0.0561
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 20 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 20 Summary:
# Accuracy: 0.2115
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 21/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 20 loss threshold: 0.0544
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 20 loss threshold: 0.0544
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 20 loss threshold: 0.0544
#
# [Training Debug] Training client 3
#
# ...
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 94 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 94 Summary:
# Accuracy: 0.4598
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 95/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 94 loss threshold: 0.0057
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 94 loss threshold: 0.0057
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 94 loss threshold: 0.0057
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 94 loss threshold: 0.0057
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 94 loss threshold: 0.0057
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 95 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 95 Summary:
# Accuracy: 0.4824
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 96/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 95 loss threshold: 0.0055
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 95 loss threshold: 0.0055
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 95 loss threshold: 0.0055
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 95 loss threshold: 0.0055
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 95 loss threshold: 0.0055
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 96 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 96 Summary:
# Accuracy: 0.5005
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 97/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 96 loss threshold: 0.0054
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 96 loss threshold: 0.0054
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 96 loss threshold: 0.0054
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 96 loss threshold: 0.0054
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 96 loss threshold: 0.0054
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 97 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 97 Summary:
# Accuracy: 0.5182
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 98/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 97 loss threshold: 0.0052
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 97 loss threshold: 0.0052
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 97 loss threshold: 0.0052
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 97 loss threshold: 0.0052
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 97 loss threshold: 0.0052
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 98 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 98 Summary:
# Accuracy: 0.5354
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 99/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 98 loss threshold: 0.0051
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 98 loss threshold: 0.0051
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 98 loss threshold: 0.0051
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 98 loss threshold: 0.0051
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 98 loss threshold: 0.0051
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 99 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 99 Summary:
# Accuracy: 0.5506
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
#
# Round 100/100
#
# [Training Debug] Training client 0
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 99 loss threshold: 0.0050
#
# [Training Debug] Training client 1
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 99 loss threshold: 0.0050
#
# [Training Debug] Training client 2
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 99 loss threshold: 0.0050
#
# [Training Debug] Training client 3
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 99 loss threshold: 0.0050
#
# [Training Debug] Training client 4
#
# [Client Debug] Starting training for 1 epochs with batch size 32
# [Debug] Round 99 loss threshold: 0.0050
#
# [Server Debug] Starting aggregation of client updates...
# [Server Debug] Warning: No parameters were updated during aggregation
#
# [Server Debug] Aggregation Statistics:
# Total clients processed: 5
# Parameters skipped: 0
# Parameters updated: 0/1625866
# Dense updates: 40
# Sparse updates: 0
# Model size: 6351.04KB
# Total download: 31755.20KB
# Total upload: 31755.20KB
# Total communication: 63510.39KB
# Compression ratio: 1.00x
#
# Per-layer communication:
#   conv1.weight: 5.62KB
#   conv1.bias: 0.62KB
#   conv2.weight: 360.00KB
#   conv2.bias: 1.25KB
#   fc1.weight: 31360.00KB
#   fc1.bias: 2.50KB
#   fc2.weight: 25.00KB
#   fc2.bias: 0.20KB
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
# [INFO] Appended round 100 metrics to results\None_mnist_detailed_logs.csv
# [Error] Failed to save metrics: All arrays must be of the same length
# Metrics lengths: {'timestamp': 1, 'round': 1, 'accuracy': 1, 'flops': 1, 'memory': 1, 'memory_saved': 1, 'communication': 1, 'sparsity': 1, 'skipped_batches': 1, 'effective_compute_ratio': 1, 'compression_ratio': 1, 'download_bytes': 1, 'upload_bytes': 1, 'model_size_bytes': 1, 'client_eval_history': 1}
#
# Round 100 Summary:
# Accuracy: 0.5607
# Communication: 62.02MB (Download: 31755.20KB, Upload: 31755.20KB)
# Model Size: 6351.04KB
# Compression Ratio: 1.00x
# Sparsity: 0.00%
# Skipped Batches: 0
# Effective Compute Ratio: 1.0000
# Error in NONIID: too many values to unpack (expected 2)
